# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.rename(columns={'patient_nbr': 'Patient ID', 'race': 'Race', 'gender': 'Gender', 'age': 'Age', 'admission_type_id': 'Admission Type', 'time_in_hospital': 'Duration of Stay', 'num_lab_procedures': 'Amount of Lab Procedures', 'num_procedures': 'Amount of Procedures', 'num_medications': 'Number of Medications', 'number_outpatient': 'Outpatient Visits', 'number_emergency': 'Emergency Room Visits', 'number_inpatient': 'Inpatient Stays', 'number_diagnoses': 'Diagnoses', 'change': 'Change', 'diabetesMed': 'Diabetes Medication', 'readmitted': 'Readmitted'})
# Out:
#         encounter_id  Patient ID  ... Diabetes Medication Readmitted
# 0            2278392     8222157  ...                  No         NO
# 1             149190    55629189  ...                 Yes        >30
# 2              64410    86047875  ...                 Yes         NO
# 3             500364    82442376  ...                 Yes         NO
# 4              16680    42519267  ...                 Yes         NO
# ...              ...         ...  ...                 ...        ...
# 101761     443847548   100162476  ...                 Yes        >30
# 101762     443847782    74694222  ...                 Yes         NO
# 101763     443854148    41088789  ...                 Yes         NO
# 101764     443857166    31693671  ...                 Yes         NO
# 101765     443867222   175429310  ...                  No         NO
#
# [101766 rows x 50 columns]

# %% [markdown]
# Correlation between Time in Hospital & Medication

# %%
#The longer the hospital stay, the more medication is being taken

# %%
df.groupby(['time_in_hospital'])['num_medications'].mean().plot(kind='bar')

# %% [markdown]
# Relationship of Emergency Room visits to Medication being taken

# %%
#There is seemingly less of a correlation to the number of emergency room visits and amount of medication being taken

# %%
sns.barplot(x='number_emergency', y='num_medications', data=df)

# %%
#I wanted to filter out specific diagnoses relative to complications with pregnancies and childbirth (categorized in the diagnoses columns ranging from 640-649) but could not figure out how to do so in the manner that I needed.
#The following did not yield the results I was seeking in the way that I was intending:
#df.groupby('diag_1').count() == '640'
#freq = df.groupby('diag_1').count() == '640'
#print(freq)
#df.groupby(['time_in_hospital', 'diag_1']).size().reset_index(name='counts')
#Although I edited the names of columns, they still showed up as is in the visualizations.
